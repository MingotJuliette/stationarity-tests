# %%
import importlib
import stationarity_tests


from stationarity_tests import stationnary

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.tsa.stattools as ts
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm

# %%
###################################################################
                       ###### Parameters #####
###################################################################

pvalue_seuil = 0.05

serie_test = pd.read_csv("ma_lga_12345.csv")
df = pd.DataFrame(serie_test["MA"])
name = "Moving Average of Median Price"

# %%
print(name)
stationnary(df, name)
# Out:
# Moving Average of Median Price
# --------------------------------------------------------------------------------------------------------
# The serie is difference-stationary (DS)
#   The first differencing is applied (ΔY_t = Y_t - Y_{t-1}).
#
# With the specification : no constant, no trend
# The P-value is : 7.518340943659207e-29. Thus, the series is stationary with an optimal number of lags equal to : 0
#
# var_dep_shift    7.559186e-50
# dtype: float64
